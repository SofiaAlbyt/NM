# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaAlbyt/NM/blob/main/%D0%9A%D0%BE%D0%BF%D1%96%D1%8F_%D0%B7%D0%B0%D0%BF%D0%B8%D1%81%D0%BD%D0%B8%D0%BA%D0%B0_%22%D0%9B%D0%A04_%D0%90%D0%BB%D1%8C%D0%B1%D0%B8%D1%82_%D0%A1_%D0%A1_%D0%B21__ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

numpy_version = np.__version__
numpy_version
# Out:
# '2.0.2'

# %%
matrix = np.random.randint(1, 6, size=(3, 3))

matrix
# Out:
# array([[1, 1, 1],
#        [5, 4, 4],
#        [1, 5, 3]])

# %%
det = np.linalg.det(matrix)
det
# Out:
# np.float64(2.0)

# %%
product = np.prod(matrix)
product
# Out:
# np.int64(1200)

# %%
prod_1 = np.prod(matrix[0])
prod_2 = np.prod(matrix[1])
prod_3 = np.prod(matrix[2])
prod_1*prod_2*prod_3
# Out:
# np.int64(1200)

# %%
np.sum(matrix)
# Out:
# np.int64(25)

# %%
np.max(matrix)
# Out:
# np.int64(5)

# %%
np.min(matrix)
# Out:
# np.int64(1)

# %%
np.mean(matrix)
# Out:
# np.float64(2.7777777777777777)

# %%
sqrt_matrix = np.sqrt(matrix)

print("Матриця квадратних коренів")
print(sqrt_matrix)
# Out:
# Матриця квадратних коренів
# [[1.         1.         1.        ]
#  [2.23606798 2.         2.        ]
#  [1.         2.23606798 1.73205081]]

# %%
print("Сума елементів кожного рядка")
np.sum(matrix, axis=1).reshape(-1, 1)
# Out:
# Сума елементів кожного рядка
# array([[ 3],
#        [13],
#        [ 9]])

# %%
matrix.sum(axis=1)
# Out:
# array([ 3, 13,  9])

# %%
x = np.matrix([[1, 2], [4, 3]])
x
# Out:
# matrix([[1, 2],
#         [4, 3]])

# %%
x.sum(axis=1, dtype="float")
# Out:
# matrix([[3.],
#         [7.]])

# %%
vector = np.random.randint(0, 10, size=25)
vector
# Out:
# array([4, 9, 3, 2, 4, 0, 7, 2, 8, 7, 4, 8, 6, 5, 3, 6, 8, 6, 7, 6, 5, 9,
#        9, 4, 0])

# %%
sorted_vector = np.sort(vector)[::1]
sorted_vector
# Out:
# array([0, 0, 2, 2, 3, 3, 4, 4, 4, 4, 5, 5, 6, 6, 6, 6, 7, 7, 7, 8, 8, 8,
#        9, 9, 9])

# %% [markdown]
# ![Знімок екрана 2026-05-08 191643.png](data:image/png;base64,...)

# %%
import numpy as np

a = np.array([
    [14, 4,  6],
    [5, -3, 2],
    [10, -11, 5],
])

b = np.array([[30], [15], [36]])

# %%
det_a = np.linalg.det(a)
if det_a == 0:
    print("Визначник дорівнює нулю — система не має єдиного розв’язку.")
else:
    a_inv = np.linalg.inv(a)
    print("Обернена матриця до матриці A:")
    print(np.round(a_inv, 3))   # округлюємо до 3 знаків після коми

    print("\nВектор рішення (матричний метод):")
    print(np.round(a_inv.dot(b), 3))
# Out:
# Обернена матриця до матриці A:
# [[-0.097  1.194 -0.361]
#  [ 0.069 -0.139 -0.028]
#  [ 0.347 -2.694  0.861]]
#
# Вектор рішення (матричний метод):
# [[ 2.]
#  [-1.]
#  [ 1.]]

# %%
if det_a == 0:
    print("Визначник дорівнює нулю — система не має єдиного розв’язку.")
else:
    def replace_column(matrix, column_index, new_column):
        new_matrix = np.copy(matrix)
        new_matrix[:, column_index] = new_column.flatten()
        return new_matrix

    delta_x = np.linalg.det(replace_column(a, 0, b))
    delta_y = np.linalg.det(replace_column(a, 1, b))
    delta_z = np.linalg.det(replace_column(a, 2, b))

    print("\nМетод Крамера:")
    print("x =", round(delta_x / det_a, 3))
    print("y =", round(delta_y / det_a, 3))
    print("z =", round(delta_z / det_a, 3))
# Out:
# Метод Крамера:
# x = 2.0
# y = -1.0
# z = 1.0

# %%
x = np.linalg.solve(a, b)
print(np.round(x, 3))
# Out:
# [[ 2.]
#  [-1.]
#  [ 1.]]
